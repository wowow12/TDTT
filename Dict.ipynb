# %%
# my_list
my_dict = {'name':'Hai','age':19} #tu dien, key la doc nhat

my_dict['que quan'] = 'Ha Noi'
my_dict['Diem TB'] = 'A+'
print (*my_dict) #unpack chi ra key thoi
for k in my_dict.keys():
    print (k, end = " ")
print ("\n")
for v in my_dict.values():
    print (v,end=" ")
for k,v in my_dict.items():
    print (f"{k},{v}")






my_set = {1,2,3,3,4,5,5}
print (len(my_set)) # tap hop, khong quan tam thu tu
print (my_set)
# Out:
# name age que quan Diem TB
# name age que quan Diem TB
#
# Hai 19 Ha Noi A+ name,Hai
# age,19
# que quan,Ha Noi
# Diem TB,A+
# 5
# {1, 2, 3, 4, 5}

# %%
# name Hai age 19 score A+
data_list = input().split()
print (data_list)
my_dict = dict()
for i in range(0,len(data_list)-1,2):
    my_dict[data_list[i]] = data_list[i+1]
print (my_dict)
my_dict.g
# Out:
# ['name', 'Hai', 'age', '19']
# {'name': 'Hai', 'age': '19'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 8
#       6     my_dict[data_list[i]] = data_list[i+1]
#       7 print (my_dict)
# ----> 8 my_dict.pop['nha':'HY']
#       9 print (my_dict)
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
print (eval('5+3'))

print (eval("['name', 'Hai', 'age', '19', 'score', 'A+']"))
# Out:
# 8
# ['name', 'Hai', 'age', '19', 'score', 'A+']

# %%
# name Hai age 19 score A+
data_list = eval(input())
print (data_list)
print (type(data_list))
# Out:
# Hai
# <class 'str'>
